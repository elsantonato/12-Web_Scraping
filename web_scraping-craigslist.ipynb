# %%
# import dependencies
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import pymongo
import matplotlib.pyplot as plt

# Output File (CSV)
output_data_file = "csv_outputs/craigslist_tools.csv"

# %%
#set the url as a variable
url = 'https://toronto.craigslist.org/search/tla?'

# %%
response = requests.get(url)

# %%
soup = bs(response.text, 'lxml')

# %%
#pretty print the parsed text
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    ﻿
#    <!DOCTYPE html>
#   </p>
#   <title>
#    toronto tools  - craigslist
#   </title>
#   <meta content="toronto tools  - craigslist" name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://toronto.craigslist.org/search/tla" rel="canonical"/>
#   <link href="https://toronto.craigslist.org/search/tla?format=rss" rel="alternate" title="RSS feed for craigslist | toronto tools  - craigslist" type="application/rss+xml"/>
#   <link href="https://toronto.craigslist.org/search/tla?s=120" rel="next"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="//www.craigslist.org/styles/cl.css?v=93aa8b9183682fd14ca12ff38c0d801c" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/search.css?v=84cf86bc094026e12fa066bbbab154ac" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
#account for pages (120 items per page)
pg_num = 120

while pg_num < 120:
    pg_num += pg_num
    if pg_num == 120:
        continue
    print(pg_num)

#set the url as a variable
url = 'https://toronto.craigslist.org/search/tla?' + str(pg_num)

# %%
results = soup.find_all('li', class_="result-row")
for item in results:
    print(item)
# Out:
# <li class="result-row" data-pid="6798256219" data-repost-of="5162754663">
# <a class="result-image gallery" data-ids="1:00V0V_bGXItJsJmJH,1:00g0g_asolMij5B9Q,1:00L0L_5JLAQ6akFCS,1:00S0S_3vmKW0Bn0Kv,1:00Y0Y_iC5TNLFlbva,1:00g0g_l5oVNPAoA8S" href="https://toronto.craigslist.org/tor/tls/d/new-toolway-3-and-4-paint-brushes/6798256219.html">
# <span class="result-price">$8</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-01-25 18:29" title="Fri 25 Jan 06:29:23 PM">Jan 25</time>
# <a class="result-title hdrlnk" data-id="6798256219" href="https://toronto.craigslist.org/tor/tls/d/new-toolway-3-and-4-paint-brushes/6798256219.html">NEW!  TOOLWAY 3" AND 4" PAINT BRUSHES</a>
# <span class="result-meta">
# <span class="result-price">$8</span>
# <span class="result-hood"> (Dufferin and Eglinton)</span>
# <span class="result-tags">
# ...

# %%
len(results)
# Out:
# 120

# %%
results[0]
# Out:
# <li class="result-row" data-pid="6798256219" data-repost-of="5162754663">
# <a class="result-image gallery" data-ids="1:00V0V_bGXItJsJmJH,1:00g0g_asolMij5B9Q,1:00L0L_5JLAQ6akFCS,1:00S0S_3vmKW0Bn0Kv,1:00Y0Y_iC5TNLFlbva,1:00g0g_l5oVNPAoA8S" href="https://toronto.craigslist.org/tor/tls/d/new-toolway-3-and-4-paint-brushes/6798256219.html">
# <span class="result-price">$8</span>
# </a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2019-01-25 18:29" title="Fri 25 Jan 06:29:23 PM">Jan 25</time>
# <a class="result-title hdrlnk" data-id="6798256219" href="https://toronto.craigslist.org/tor/tls/d/new-toolway-3-and-4-paint-brushes/6798256219.html">NEW!  TOOLWAY 3" AND 4" PAINT BRUSHES</a>
# <span class="result-meta">
# <span class="result-price">$8</span>
# <span class="result-hood"> (Dufferin and Eglinton)</span>
# <span class="result-tags">
# ...

# %%
results[0].find('a', class_="result-title").text.strip()
# Out:
# 'NEW!  TOOLWAY 3" AND 4" PAINT BRUSHES'

# %%
results[0].find('span', class_="result-price").text.strip()
# Out:
# '$8'

# %%
print('https://toronto.craigslist.org' + results[0].find('a', class_="result-title hdrlnk")['href'])
# Out:
# https://toronto.craigslist.orghttps://toronto.craigslist.org/tor/tls/d/new-toolway-3-and-4-paint-brushes/6798256219.html

# %%
results = soup.find_all('li', class_="result-row")
title_list = []
price_list = []
link_list = []

#loop through returned results
for result in results:
    #error handling
    try: 
        #identify and return title of listing
        title = result.find('a', class_="result-title").text.strip()
        #identify and return price of listing
        price = result.find('span', class_="result-price").text.strip()
        #identify and return link to listing
        link = 'https://toronto.craigslist.org' + result.find('a', class_="result-title hdrlnk")['href']
        #link = f'https://www.homedepot.ca'/{result.find('a', itemprop="url")['href']}
        
        title_list.append(title)
        price_list.append(price)
        link_list.append(link)
        
    except AttributeError as e:
        print(e)
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'

# %%
df = pd.DataFrame({"title": title_list, "price": price_list, "link": link_list})
#df = pd.DataFrame({"title": title_list, "price": price_list})

# %%
df
# Out:
#                                                  title  price  \
# 0                NEW!  TOOLWAY 3" AND 4" PAINT BRUSHES     $8
# 1    NEW! CANADA PRO-FIX 24 and 30 INCH BOW SAW BLADES     $6
# 2                      NEW!  MATRIX 7pc NUT DRIVER SET    $15
# 3    NEW!  30m/100ft REWINDING SURVEYOR'S MEASURING...    $17
# 4    F1.2x710 28-Inch ,Easy Operation Sheet Metal F...   $575
# 5                    52-Inch Foot Stomp Shear Q01-5216  $2199
# 6                                Old Wooden Yard Stick     $4
# 7                      makita cordless band saw blades    $45
# 8               KNIPEX AND KLEIN TOOLS FOR ELECTRICIAN   $385
# 9        7 inch Cutting Metal Cutting Band Saw BS-712R  $1799
# 10   Hs-1000 Gauge Sheet Metal Fabrication Plate Cu...   $699
# 11           Cordless Drill 1/2" & Corded Hammer Drill    $85
# 12   2 Wheel Moving Dolly or Hand Truck- Heavy Duty...    $40
# 13   Kaka Industrial TR-60 Manual Tube Pipe Roller ...   $454
# ...

# %%
# output to csv
df.to_csv("csv_outputs/craigslist_tools.csv")
