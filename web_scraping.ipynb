# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
url = 'https://www.kijiji.ca/b-city-of-toronto/carpenter-tools/k0l1700273?dc=true'

# %%
response = requests.get(url)

# %%
for line in response:
    print(line)
# Out:
# b'<!DOCTYPE html>\n<!--[if lte IE 8]><html id="reset" class="ie8" lang="en"><![endif]-->\n<!--[if IE 9]><html id="reset" class="ie9"'
# b' lang="en"><![endif]-->\n<!--[if gt IE 9]><!--><html id="reset" lang="en"><!--<![endif]-->\n<!--[if !IE]><!--><html id="reset" lan'
# b'g="en"><!--<![endif]-->\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\n    <link rel="preload" href="https:'
# b'//ca.classistatic.com/static/V/7738/css/master.theme.css" as="style" />\n    <link rel="preload" href="https://ca.classistatic.co'
# b'm/static/V/7738/js/bootstrap.js" as="script" />\n    <link rel="preload" href="https://ca.classistatic.com/static/V/7738/js/commo'
# b'n.js" as="script" />\n\n    <link rel="preload" href="//ca.classistatic.com/service-static/frontend-service/Larsseit.92161b1b.woff'
# b'2" as="font" type="font/woff2" crossorigin />\n<link rel="preload" href="//ca.classistatic.com/service-static/frontend-service/La'
# b'rsseitMedium.265c8042.woff2" as="font" type="font/woff2" crossorigin /><link rel="preload" href="//ca.classistatic.com/service-s'
# b'tatic/frontend-service/styles.726b058a3fc994143f12.css" as="style" /><link rel="preload" href="//ca.classistatic.com/service-sta'
# b'tic/frontend-service/runtime.bf176b67.js" as="script" />\n<link rel="preload" href="//ca.classistatic.com/service-static/frontend'
# b'-service/vendor.de954107.js" as="script" />\n<link rel="preload" href="//ca.classistatic.com/service-static/frontend-service/app.'
# b'7d1b819a.js" as="script" />\n<link rel="preload" href="//ca.classistatic.com/service-static/frontend-service/ebaySponsor.a7388f8e'
# b'.js" as="script" />\n<link rel="preload" href="//ca.classistatic.com/service-static/frontend-service/searchResults.9588eb8e.js" a'
# b's="script" />\n<link rel="preload" href="//ca.classistatic.com/service-static/frontend-service/alertPrompt.fc739c9b.js" as="scrip'
# b't" />\n<link rel="preload" href="//ca.classistatic.com/service-static/frontend-service/footer.42dd630f.js" as="script" />\n<link r'
# b'el="preload" href="//ca.classistatic.com/service-static/frontend-service/header.a9fab8ed.js" as="script" />\n<link rel="preload" '
# b'href="//ca.classistatic.com/service-static/frontend-service/en-i18n-json.b230d604.js" as="script" />\n<link rel="preload" href="/'
# b'/ca.classistatic.com/service-static/frontend-service/styles.f604c49d.js" as="script" />\n<link rel="preload" href="//ca.classista'
# b'tic.com/service-static/frontend-service/svg.f37dae65.js" as="script" /><title>Carpenter Tools | Best Local Deals on Tools, Mecha'
# b'nics, Gadgets &amp; more in City of Toronto | Kijiji Classifieds</title>\n\n    <link rel="apple-touch-icon" sizes="180x180" href='
# b'"https://ca.classistatic.com/static/V/7738/img/favicons/apple-touch-icon-new.png">\n<link rel="icon" type="image/png" href="https'
# b'://ca.classistatic.com/static/V/7738/img/favicons/favicon-32x32-new.png" sizes="32x32">\n<link rel="icon" type="image/png" href="'
# b'https://ca.classistatic.com/static/V/7738/img/favicons/favicon-16x16-new.png" sizes="16x16">\n<link rel="manifest" href="/manifes'
# b't.json">\n<link rel="mask-icon" href="https://ca.classistatic.com/static/V/7738/img/favicons/safari-pinned-tab.svg" color="#2c2f6'
# b'b">\n<link rel="shortcut icon" href="https://ca.classistatic.com/static/V/7738/img/favicons/faviconNew.ico">\n<meta name="apple-mo'
# b'bile-web-app-title" content="Kijiji">\n<meta name="application-name" content="Kijiji">\n<meta name="msapplication-config" content='
# b'"/browserconfig.xml">\n<meta name="theme-color" content="#2c2f6b">\n<link rel="publisher" href="https://plus.google.com/+KijijiCan'
# b'ada" />\n    <meta name="description" content="Find Carpenter Tools in Tools | Buy or sell tools in City of Toronto \xe2\x80\x93 Dewalt, B'
# b'osch, Hilti, Makita, Snap On, find an axe, saw, hammer, tool box or bench and more on Kijiji, Canada&#039;s #1 Local Classifieds'
# b'."/><meta name="keywords" content="Kijiji, Find, Ads, Carpenter Tools"/><meta name="robots" content="INDEX,FOLLOW"/>\n           '
# b'<meta name="apple-itunes-app" content="app-id=318979520"/>\n\n    <meta name="viewport" content="width=device-width, initial-scale'
# b'=1.0"/>\n\n    <meta property="og:site_name" content="Kijiji"/>\n    <meta property="og:country-name" content="Canada"/>\n    <meta '
# b'http-equiv="content-type" content="text/html; charset=UTF-8"/>\n\n<meta name="msvalidate.01" content="E03E7C8B4B4E1A0234A8D2042FD3'
# b'26E8" />\n\n<meta name="yandex-verification" content="1ca862e94bc07ad7" />\n\n    <meta name="google" content="nositelinkssearchbox"'
# b'>\n\n    <meta http-equiv="content-language" content="en">\n\n    <meta property="og:image" content="https://ca.classistatic.com/sta'
# b'tic/V/7738/img/fb_desktop.jpg"/><meta property="og:type" content="website"/><meta property="og:description" content="Find Carpen'
# b'ter Tools in Tools | Buy or sell tools in City of Toronto \xe2\x80\x93 Dewalt, Bosch, Hilti, Makita, Snap On, find an axe, saw, hammer, t'
# b'ool box or bench and more on Kijiji, Canada&#039;s #1 Local Classifieds."/><meta property="og:title" content="Kijiji Canada"/><l'
# b'ink rel="canonical" href="https://www.kijiji.ca/b-tool/city-of-toronto/carpenter-tools/k0c110l1700273"/><link rel="alternate" hr'
# b'eflang="x-default" href="https://www.kijiji.ca/b-tool/city-of-toronto/carpenter-tools/k0c110l1700273" /><link rel="alternate" hr'
# b'ef="https://www.kijiji.ca/b-tool/city-of-toronto/carpenter-tools/k0c110l1700273?siteLocale=fr_CA" hreflang="fr" />\n    <script t'
# b'ype="application/ld+json">\n{ "@context" : "https://schema.org",\n  "@type" : "Organization",\n  "name" : "Kijiji Canada",\n  "alter'
# b'nateName" : "Kijiji",\n  "url" : "https://www.kijiji.ca/",\n  "sameAs" : [\n    "https://www.facebook.com/Kijiji.ca/",\n    "https:/'
# b'/twitter.com/Kijiji",\n    "https://plus.google.com/+KijijiCanada",\n    "https://www.youtube.com/user/kijijicanadacorp",\n    "htt'
# b'ps://www.linkedin.com/company/kijiji-an-ebay-company",\n    "https://www.wikidata.org/wiki/Q1741191"\n  ],\n  "logo": https://ca.cl'
# b'assistatic.com/static/V/7738/img/Kijiji-Canada-Logo-1.jpg\n}\n</script>\n<link rel="stylesheet" type="text/css" href="https://ca.cl'
# b'assistatic.com/static/V/7738/css/master.theme.css"/>\n    <link rel="stylesheet" type="text/css" href="https://ca.classistatic.co'
# b'm/static/V/7738/css/srp.theme.css"/>\n    <link rel="stylesheet" type="text/css" href="https://ca.classistatic.com/static/V/7738/'
# b'css/redesign.theme.css"/>\n    <link rel="stylesheet" type="text/css" href="https://ca.classistatic.com/static/V/7738/css/redesig'
# b'n-postad.theme.css"/>\n\n    <link rel="stylesheet" type="text/css" href="//ca.classistatic.com/service-static/frontend-service/st'
# b'yles.726b058a3fc994143f12.css" /><script src="https://ca.classistatic.com/static/V/7738/js/bootstrap.js"></script>\n\n    <!--[if '
# b'lte IE 8]><script defer src="https://ca.classistatic.com/static/V/7738/js/ie8.js"></script><![endif]-->\n    <script defer src="/'
# b'/cdn.optimizely.com/js/2217630246.js"></script>\n<script>\nvar googletag = googletag || {};\ngoogletag.cmd = googletag.cmd || [];\n\n'
# b'var gptMasterAdData = gptMasterAdData || {};\nvar gptCTMAdData = gptCTMAdData || {};\nvar gptSizeMaps = gptSizeMaps || {};\nvar gpt'
# b'AdSlots = gptAdSlots || {};\nvar gptAdTargeting = gptAdTargeting || [];\nvar gptBannerSizeMapping = gptBannerSizeMapping || [];\n</'
# b'script>\n\n<script>\n        gptSizeMaps.leaderBoard = {\n            breakPoint: [760, 990],\n            responsive: [\n            '
# b'    { minWidth: 990, sizes: [[728, 90], [970, 90]] },\n                { minWidth: 760, sizes: [728, 90] },\n                { min'
# b'Width: 0, sizes: [] }\n            ]\n        };\n        gptSizeMaps.inlineBanner = {\n            breakPoint: 961,\n            res'
# b'ponsive: [\n                { minWidth: 961, sizes: [728, 90] },\n                { minWidth: 0, sizes: [[300, 250], [320, 50], [3'
# b'00, 150]] }\n            ]\n        };\n        gptSizeMaps.baseBanner = {\n            breakPoint: [751, 991],\n            responsi'
# b've: [\n                { minWidth: 991, sizes: [[728, 90], [970, 250], [970, 90]] },\n                { minWidth: 751, sizes: [728'
# b', 90] },\n                { minWidth: 0, sizes: [[300, 250], [320, 50], [300, 150]] }\n            ]\n        };\n        gptSizeMap'
# b's.skyscraperBanner = {\n            breakPoint: [751, 1059],\n            responsive: [\n                { minWidth: 1059, sizes: ['
# b'[300, 600], [300, 250], [160, 600]] },\n                { minWidth: 751, sizes: [160, 600] },\n                { minWidth: 0, size'
# b's: [] }\n            ]\n        };\n        gptSizeMaps.stlBanner = {\n            breakPoint: 840,\n            responsive: [\n      '
# b'          { minWidth: 840, sizes: [[575, 90],[575, 210]] },\n                { minWidth: 0, sizes: [350, 90] }\n            ]\n    '
# b'    };\n        gptSizeMaps.topCallToDFPBanner = {\n            breakPoint: 840,\n            responsive: [\n                { minWi'
# b'dth: 840, sizes: [[575, 200]] },\n                { minWidth: 0, sizes: [350, 95] }\n            ]\n        };\n        gptSizeMaps.'
# b'sticky = {\n            breakPoint: 760,\n            responsive: [\n                { minWidth: 760, sizes: [] },\n                '
# b"{ minWidth: 0, sizes: [320, 50] }\n            ]\n        };\n        </script><script>\n        \n\ngptMasterAdData['gpt-leaderboard-"
# b"top'] = {\n    id: 'gpt-leaderboard-top',\n    slot: '/5138/kij.ca.buyandsell/tools/srp',\n    sizes: [[728, 90],[970, 90]],sizeMap"
# b"ping: gptSizeMaps.leaderBoard,tile: '1',pos: 'top',\n    collapse: false,\n    isBiddable: true\n};\n\n\n    gptBannerSizeMapping.push"
# b"({\n        name: 'gpt-leaderboard-top',\n        breakPoint: gptSizeMaps.leaderBoard.breakPoint\n    });\n\n\ngptMasterAdData['gpt-sk"
# b"yscraper'] = {\n    id: 'gpt-skyscraper',\n    slot: '/5138/kij.ca.buyandsell/tools/srp',\n    sizes: [[300, 600],[300, 250],[160, "
# b"600]],sizeMapping: gptSizeMaps.skyscraperBanner,tile: '2',pos: 'top',\n    collapse: false,\n    isBiddable: true\n};\n\n\n    gptBann"
# b"erSizeMapping.push({\n        name: 'gpt-skyscraper',\n        breakPoint: gptSizeMaps.skyscraperBanner.breakPoint\n    });\n\n\ngptMa"
# b"sterAdData['gpt-minileaderboard-base'] = {\n    id: 'gpt-minileaderboard-base',\n    slot: '/5138/kij.ca.buyandsell/tools/srp',\n  "
# b"  sizes: [[575, 90],[575, 210]],sizeMapping: gptSizeMaps.stlBanner,tile: '5',\n    collapse: false,\n    isBiddable: false\n};\n\n\n  "
# b"  gptBannerSizeMapping.push({\n        name: 'gpt-minileaderboard-base',\n        breakPoint: gptSizeMaps.stlBanner.breakPoint\n   "
# b" });\n\n\ngptMasterAdData['gpt-minileaderboard-top'] = {\n    id: 'gpt-minileaderboard-top',\n    slot: '/5138/kij.ca.buyandsell/tool"
# b"s/srp',\n    sizes: [[575, 200]],sizeMapping: gptSizeMaps.topCallToDFPBanner,tile: '5',\n    collapse: true,\n    isBiddable: false"
# b"\n};\n\n\n    gptBannerSizeMapping.push({\n        name: 'gpt-minileaderboard-top',\n        breakPoint: gptSizeMaps.topCallToDFPBanne"
# b"r.breakPoint\n    });\n\n\ngptMasterAdData['gpt-leaderboard-base'] = {\n    id: 'gpt-leaderboard-base',\n    slot: '/5138/kij.ca.buyan"
# b"dsell/tools/srp',\n    sizes: [[728, 90],[970, 250]],sizeMapping: gptSizeMaps.baseBanner,tile: '4',pos: 'base',\n    collapse: fal"
# b"se,\n    isBiddable: true\n};\n\n\n    gptBannerSizeMapping.push({\n        name: 'gpt-leaderboard-base',\n        breakPoint: gptSizeM"
# b"aps.baseBanner.breakPoint\n    });\n\n\ngptMasterAdData['gpt-top-srp'] = {\n    id: 'gpt-top-srp',\n    slot: '/5138/kij.ca.buyandsell"
# b"/tools/srp',\n    sizes: [[728, 90], [728, 300]],sizeMapping: gptSizeMaps.inlineBanner,tile: '3',pos: 'bottom',\n    collapse: tru"
# b"e,\n    isBiddable: true\n};\n\n\n    gptBannerSizeMapping.push({\n        name: 'gpt-top-srp',\n        breakPoint: gptSizeMaps.inline"
# b"Banner.breakPoint\n    });\n\n\ngptMasterAdData['gpt-inline-srp'] = {\n    id: 'gpt-inline-srp',\n    slot: '/5138/kij.ca.buyandsell/t"
# b"ools/srp',\n    sizes: [[728, 90], [728, 300]],sizeMapping: gptSizeMaps.inlineBanner,tile: '6',pos: 'bottom2',\n    collapse: true"
# b",\n    isBiddable: true\n};\n\n\n    gptBannerSizeMapping.push({\n        name: 'gpt-inline-srp',\n        breakPoint: gptSizeMaps.inli"
# b"neBanner.breakPoint\n    });\n\n\ngptMasterAdData['gpt-sticky'] = {\n    id: 'gpt-sticky',\n    slot: '/5138/kij.ca.buyandsell/tools/s"
# b"rp',\n    sizes: [[320, 50]],sizeMapping: gptSizeMaps.sticky,tile: '7',pos: 'top',\n    collapse: false,\n    isBiddable: false\n};\n"
# b"\n\n    gptBannerSizeMapping.push({\n        name: 'gpt-sticky',\n        breakPoint: gptSizeMaps.sticky.breakPoint\n    });\n</script"
# b"><script>\n    \n        gptAdTargeting.push({ key: 'pagetype', value: 'srp' });\n    \n        gptAdTargeting.push({ key: 'sub', va"
# b"lue: 'cityoftoronto' });\n    \n        gptAdTargeting.push({ key: 'ab', value: '0' });\n    \n        gptAdTargeting.push({ key: 'p"
# b'tg\', value: ["KCA23868_0", "KCA26723_1", "KCA28709_1", "KCA28833_0", "KCA29068_1", "KCA29114_-99", "KCA30002_0"] });\n    \n      '
# b"  gptAdTargeting.push({ key: 'pt', value: 'ResultsSearch' });\n    \n        gptAdTargeting.push({ key: 'city', value: 'torontogta"
# b"' });\n    \n        gptAdTargeting.push({ key: 'l1', value: 'buyandsell' });\n    \n        gptAdTargeting.push({ key: 'ot', value:"
# b" '1' });\n    \n        gptAdTargeting.push({ key: 'g_pn', value: '1' });\n    \n        gptAdTargeting.push({ key: 'reg_user', valu"
# b"e: 'no' });\n    \n        gptAdTargeting.push({ key: 'l2', value: 'tools' });\n    \n        gptAdTargeting.push({ key: 'hn', value"
# b": 'kijiji.ca' });\n    \n        gptAdTargeting.push({ key: 'kw', value: 'carpenter tools' });\n    \n        gptAdTargeting.push({ "
# b"key: 'ct', value: '110' });\n    \n        gptAdTargeting.push({ key: 'catid', value: '110' });\n    \n        gptAdTargeting.push({"
# b" key: 'dv', value: 'd' });\n    \n        gptAdTargeting.push({ key: 'HBL', value: 'yes' });\n    \n        gptAdTargeting.push({ ke"
# b"y: 'province', value: 'ontario' });\n    \n        gptAdTargeting.push({ key: 'forsaleby', value: 'owner' });\n    \n        gptAdTa"
# b"rgeting.push({ key: 'g_prebid_version', value: '1.25.0' });\n    \n        gptAdTargeting.push({ key: 'lc', value: '1700273' });\n "
# b"   \n        gptAdTargeting.push({ key: 'um', value: '0' });\n    \n        gptAdTargeting.push({ key: 'li', value: 'no' });\n    \n "
# b"       gptAdTargeting.push({ key: 'locid', value: '1700273' });\n    \n        gptAdTargeting.push({ key: 'pagetest', value: 'larg"
# b"erimagessrp' });\n    </script>\n\n<script>\nvar pbPartnerConfig = pbPartnerConfig || [];\n\n\n    pbPartnerConfig.push({\n        id: '"
# b"aol',\n        cpmAdjustment: 0.88,\n        params: {\n            'gpt-rightrail-top':    { network: '9970.1', placement: '442849"
# b"2' },'gpt-rightrail-bottom': { network: '9970.1', placement: '4428494' },'gpt-vip-leader':       { network: '9970.1', placement:"
# b" '4428491' },'GPTBigbox':            { network: '9970.1', placement: '4428490' },'gpt-leaderboard-top':  { network: '9970.1', pl"
# b"acement: '4428546' },'gpt-top-srp':          { network: '9970.1', placement: '4428515' },'gpt-inline-srp':       { network: '997"
# b"0.1', placement: '4428522' },'gpt-leaderboard-base': { network: '9970.1', placement: '4428520' },'gpt-skyscraper':       { netwo"
# b"rk: '9970.1', placement: '4428518' },'gpt-leader-bottom':    { network: '9970.1', placement: '4428494' }\n        }\n    });\n\n    "
# b"pbPartnerConfig.push({\n        id: 'appnexus',\n        cpmAdjustment: 1,\n        params: {\n            'ImageLeaderBoard':     {"
# b" placementId: '10477092' },'gpt-r2s-vip':          { placementId: '10477092' },'gpt-posted-vip':       { placementId: '10477092'"
# b" },'gpt-rightrail-top':    { placementId: '10477237' },'gpt-rightrail-bottom': { placementId: '10477240' },'gpt-vip-leader':    "
# b"   { placementId: '10477242' },'GPTBigbox':            { placementId: '10477243' },'gpt-leaderboard-top':  { placementId: '10477"
# b"244' },'gpt-top-srp':          { placementId: '10477245' },'gpt-inline-srp':       { placementId: '10477246' },'gpt-leaderboard-"
# b"base': { placementId: '10477247' },'gpt-skyscraper':       { placementId: '10477248' },'gpt-leader-bottom':    { placementId: '1"
# b"0477240' }\n        }\n    });\n\n    pbPartnerConfig.push({\n        id: 'districtm',\n        cpmAdjustment: 0.9,\n        params: {\n"
# b"            'ImageLeaderBoard':     { placementId: 9836668 },'gpt-r2s-vip':          { placementId: 9836668 },'gpt-posted-vip': "
# b"      { placementId: 9836668 },'gpt-rightrail-top':    { placementId: 9836669 },'gpt-rightrail-bottom': { placementId: 9836670 }"
# b",'gpt-vip-leader':       { placementId: 7058027 },'GPTBigbox':            { placementId: 9527288 },'gpt-leaderboard-top':  { pla"
# b"cementId: 9809409 },'gpt-top-srp':          { placementId: 9527281 },'gpt-inline-srp':       { placementId: 7058031 },'gpt-leade"
# b"rboard-base': { placementId: 9527289 },'gpt-skyscraper':       { placementId: 9527292 },'gpt-leader-bottom':    { placementId: 9"
# b"836670 }\n        }\n    });\n\n    pbPartnerConfig.push({\n        id: 'districtmDMX',\n        cpmAdjustment: 0.9,\n        params: {"
# b"\n            'ImageLeaderBoard':     { dmxid: 130920, memberid: 100153 },'gpt-r2s-vip':          { dmxid: 130920, memberid: 1001"
# b"53 },'gpt-posted-vip':       { dmxid: 130920, memberid: 100153 },'gpt-rightrail-top':    { dmxid: 130921, memberid: 100153 },'gp"
# b"t-rightrail-bottom': { dmxid: 130922, memberid: 100153 },'gpt-vip-leader':       { dmxid: 116615, memberid: 100153 },'GPTBigbox'"
# b":            { dmxid: 127055, memberid: 100153 },'gpt-leaderboard-top':  { dmxid: 129907, memberid: 100153 },'gpt-top-srp':     "
# b"     { dmxid: 127050, memberid: 100153 },'gpt-inline-srp':       { dmxid: 116617, memberid: 100153 },'gpt-leaderboard-base': { d"
# b"mxid: 127056, memberid: 100153 },'gpt-skyscraper':       { dmxid: 127058, memberid: 100153 },'gpt-leader-bottom':    { dmxid: 13"
# b"0922, memberid: 100153 }\n        }\n    });\n\n    pbPartnerConfig.push({\n        id: 'ix',\n        cpmAdjustment: 1,\n        param"
# b"s: {\n            'ImageLeaderBoard':     { siteId: '190665' },'gpt-r2s-vip':          { siteId: '190665' },'gpt-posted-vip':    "
# b"   { siteId: '190665' },'gpt-rightrail-top':    { siteId: '190666' },'gpt-rightrail-bottom': { siteId: '190667' },'gpt-vip-leade"
# b"r':       { siteId: '190668' },'GPTBigbox':            { siteId: '190669' },'gpt-leaderboard-top':  { siteId: '190663' },'gpt-to"
# b"p-srp':          { siteId: '190670' },'gpt-inline-srp':       { siteId: '190671' },'gpt-leaderboard-base': { siteId: '190672' },"
# b"'gpt-skyscraper':       { siteId: '190673' },'gpt-leader-bottom':    { siteId: '190667' }\n        }\n    });\n\n    pbPartnerConfig"
# b".push({\n        id: 'openx',\n        cpmAdjustment: 0.85,\n        params: {\n            'ImageLeaderBoard':     { delDomain: 'ki"
# b"jiji-d.openx.net', unit: '538714686' },'gpt-r2s-vip':          { delDomain: 'kijiji-d.openx.net', unit: '538714686' },'gpt-poste"
# b"d-vip':       { delDomain: 'kijiji-d.openx.net', unit: '538714686' },'gpt-rightrail-top':    { delDomain: 'kijiji-d.openx.net', "
# b"unit: '538714687' },'gpt-rightrail-bottom': { delDomain: 'kijiji-d.openx.net', unit: '538714688' },'gpt-vip-leader':       { del"
# b"Domain: 'kijiji-d.openx.net', unit: '538714689' },'GPTBigbox':            { delDomain: 'kijiji-d.openx.net', unit: '538714690' }"
# b",'gpt-leaderboard-top':  { delDomain: 'kijiji-d.openx.net', unit: '538714691' },'gpt-top-srp':          { delDomain: 'kijiji-d.o"
# b"penx.net', unit: '538714692' },'gpt-inline-srp':       { delDomain: 'kijiji-d.openx.net', unit: '538714693' },'gpt-leaderboard-b"
# b"ase': { delDomain: 'kijiji-d.openx.net', unit: '538714694' },'gpt-skyscraper':       { delDomain: 'kijiji-d.openx.net', unit: '5"
# b"38714696' },'gpt-leader-bottom':    { delDomain: 'kijiji-d.openx.net', unit: '538714688' }\n        }\n    });\n\n    pbPartnerConfi"
# b"g.push({\n        id: 'pubmatic',\n        cpmAdjustment: 0.92,\n        params: {\n            'ImageLeaderBoard':     { publisherI"
# b"d: '155984', adSlot: 'PUBMATIC_ADFLOW_TOP_ENGLISH_728x90@728x90' },'gpt-r2s-vip':          { publisherId: '155984', adSlot: 'PUB"
# b"MATIC_ADFLOW_TOP_ENGLISH_728x90@728x90' },'gpt-posted-vip':       { publisherId: '155984', adSlot: 'PUBMATIC_ADFLOW_TOP_ENGLISH_"
# b"728x90@728x90' },'gpt-rightrail-top':    { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_TOP_ENGLISH_300x250@300x250' },'gpt"
# b"-rightrail-bottom': { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_BOTTOM_ENGLISH_300x250@300x250' },'gpt-vip-leader':     "
# b"  { publisherId: '155984', adSlot: 'PUBMATIC_VIEW_ITEM_PAGE_TOP_ENGLISH_728x90@728x90' },'GPTBigbox':            { publisherId: "
# b"'155984', adSlot: 'PUBMATIC_VIEW_ITEM_PAGE_BOTTOM_ENGLISH_300x250@300x250' },'gpt-leaderboard-top':  { publisherId: '155984', ad"
# b"Slot: 'PUBMATIC_SEARCH_RESULTS_PAGE_TOP_ENGLISH_728x90@728x90' },'gpt-top-srp':          { publisherId: '155984', adSlot: 'PUBMA"
# b"TIC_SEARCH_RESULTS_PAGE_INLINE1_ENGLISH_728x90@728x90' },'gpt-inline-srp':       { publisherId: '155984', adSlot: 'PUBMATIC_SEAR"
# b"CH_RESULTS_PAGE_INLINE2_ENGLISH_728x90@728x90' },'gpt-leaderboard-base': { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESUL"
# b"TS_PAGE_BASEBOARD_ENGLISH_728x90@728x90' },'gpt-skyscraper':       { publisherId: '155984', adSlot: 'PUBMATIC_SEARCH_RESULTS_PAG"
# b"E_LEFT_RAIL_ENGLISH_160x600@160x600' },'gpt-leader-bottom':    { publisherId: '155984', adSlot: 'PUBMATIC_HOMEPAGE_BOTTOM_ENGLIS"
# b"H_300x250@300x250' }\n        }\n    });\n\n    pbPartnerConfig.push({\n        id: 'rubicon',\n        cpmAdjustment: 1,\n        para"
# b"ms: {\n            'ImageLeaderBoard':     { siteId: '45324', accountId: '12230', zoneId: '582460' },'gpt-r2s-vip':          { si"
# b"teId: '45324', accountId: '12230', zoneId: '582460' },'gpt-posted-vip':       { siteId: '45324', accountId: '12230', zoneId: '58"
# b"2460' },'gpt-rightrail-top':    { siteId: '45324', accountId: '12230', zoneId: '582464' },'gpt-rightrail-bottom': { siteId: '453"
# b"24', accountId: '12230', zoneId: '582466' },'gpt-vip-leader':       { siteId: '45324', accountId: '12230', zoneId: '582470' },'G"
# b"PTBigbox':            { siteId: '45324', accountId: '12230', zoneId: '582472' },'gpt-leaderboard-top':  { siteId: '45324', accou"
# b"ntId: '12230', zoneId: '582474' },'gpt-top-srp':          { siteId: '45324', accountId: '12230', zoneId: '582476' },'gpt-inline-"
# b"srp':       { siteId: '45324', accountId: '12230', zoneId: '582478' },'gpt-leaderboard-base': { siteId: '45324', accountId: '122"
# b"30', zoneId: '582480' },'gpt-skyscraper':       { siteId: '45324', accountId: '12230', zoneId: '582482' },'gpt-leader-bottom':  "
# b"  { siteId: '45324', accountId: '12230', zoneId: '582466' }\n        }\n    });\n\n    pbPartnerConfig.push({\n        id: 'criteo',\n"
# b"        cpmAdjustment: 1,\n        params: {\n            'ImageLeaderBoard':     { zoneId: '1257525' },'gpt-r2s-vip':          { "
# b"zoneId: '1257525' },'gpt-posted-vip':       { zoneId: '1257525' },'gpt-rightrail-top':    { zoneId: '1257543' },'gpt-rightrail-b"
# b"ottom': { zoneId: '1257537' },'gpt-vip-leader':       { zoneId: '1257526' },'GPTBigbox':            { zoneId: '1257538' },'gpt-l"
# b"eaderboard-top':  { zoneId: '1257527' },'gpt-top-srp':          { zoneId: '1257533' },'gpt-inline-srp':       { zoneId: '1257534"
# b"' },'gpt-leaderboard-base': { zoneId: '1257531' },'gpt-skyscraper':       { zoneId: '1257539' }\n        }\n    });\n</script>\n<scr"
# b'ipt>\nvar pbjs = pbjs || {};\npbjs.que = pbjs.que || [];\n\n\n\nvar PREBID_TIMEOUT = 2000;\nvar PREBID_CPM_MAX = 5.00;\n\n\nif (pbPartnerC'
# b'onfig.length > 0) {\n\n    \n    var prebidAdUnits = prebidAdUnits || [];\n    var prebidCpmSums = prebidCpmSums || {};\n    var preb'
# b'idSizes = prebidSizes || [];\n    Kj.Banners.Bidding.constructPrebidAdUnitsV1();\n\n    \n    Kj.Banners.Bidding.enableBidderSetting'
# b's();\n\n    \n    if (prebidAdUnits.length > 0) {\n\n        \n        pbjs.que.push(function() {\n            pbjs.setConfig({\n       '
# b'         sizeConfig: prebidSizes,\n                userSync: {\n                    iframeEnabled: true,\n                    filte'
# b"rSettings: {\n                        iframe: {\n                            bidders: '*',\n                            filter: 'in"
# b"clude'\n                        }\n                    }\n                }\n            });\n            pbjs.onEvent('bidResponse',"
# b" Kj.Banners.Bidding.monitorCpmTotals);\n            pbjs.aliasBidder('appnexus', 'districtm');\n        });\n\n        \n        (fun"
# b"ction() {\n            var pbjsEl = document.createElement('script');\n            pbjsEl.type = 'text/javascript';\n            pb"
# b"jsEl.async = true;\n            pbjsEl.src = 'https://ca.classistatic.com/static/V/7738/js/lib/prebid-1.25.0.min.js';\n           "
# b" var pbjsTargetEl = document.getElementsByTagName('head')[0];\n            pbjsTargetEl.insertBefore(pbjsEl, pbjsTargetEl.firstCh"
# b'ild);\n        })();\n\n        \n        Kj.Banners.Bidding.requestBidsBeforeGPT(prebidAdUnits, PREBID_TIMEOUT);\n    }\n}\n\n</script>'
# b"\n<script>\n\n\n(function () {\n    var gads = document.createElement('script');\n    gads.async = true;\n    gads.type = 'text/javascr"
# b"ipt';\n    var useSSL = 'https:' == document.location.protocol;\n    gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagse"
# b"rvices.com/tag/js/gpt.js';\n    var node = document.getElementsByTagName('script')[0];\n    node.parentNode.insertBefore(gads, nod"
# b'e);\n})();\n\n\nKj.Banners.Init.pushAdSizeMaps();\nKj.Banners.Init.pushAdSlots();\nKj.Banners.Init.pushAdTargeting();\n\n\ngoogletag.cmd.'
# b"push(function() {\n    googletag.pubads().set('adsense_background_color', 'FFFFFF');\n\n    \n\n    googletag.enableServices();\n\n    "
# b'\n});\n\n</script>\n<!-- Google Tag Manager -->\n<script>\nvar dataLayer = [{"p":{"t":"ResultsSearch","pl":"Wildebeest","v":"7738","ln'
# b'g":"en_CA","vt":"LST","ua":"python-requests/2.19.1"},"c":{"c":{"id":110,"n":"Tools"},"l0":{"id":0,"n":"Classifieds"},"l1":{"id":'
# b'10,"n":"Buy \\u0026 Sell"},"l2":{"id":110,"n":"Tools"}},"l":{"c":{"id":1700273,"n":"City of Toronto"},"l0":{"id":0,"n":"Canada"},'
# b'"l1":{"id":9004,"n":"Ontario"},"l2":{"id":1700272,"n":"Toronto (GTA)"},"l3":{"id":1700273,"n":"City of Toronto"},"d":""},"u":{"l'
# b'i":false,"tg":{"stg":"KCA29114=-99;KCA30002=0;KCA29068=1;KCA28833=0;KCA28709=1;KCA26723=1;KCA23868=0","pagetest":"largerimagessr'
# b'p"}},"d":{"ua":"python-requests/2.19.1"},"s":{"kw":"carpenter tools","dc":110,"dcr":true,"dcp":false,"dcc":"0.92","tr":9,"pn":1,'
# b'"tp":1,"ps":20,"prc":{},"attr":{},"attrMin":{},"attrMax":{},"srt":{"f":"date","dr":"DESC"},"u":{"li":false,"tg":{"stg":"","paget'
# b'est":"largerimagessrp"}},"sr":[{"id":"1207201","pos":1,"rt":"CAS;topad","cr":""},{"id":"472841","pos":2,"rt":"partner_cas","cr":'
# b'""},{"id":"1219927414","pos":3,"rt":"organic","cr":""},{"id":"1207201","pos":4,"rt":"partner_cas","cr":""},{"id":"1407417277","p'
# b'os":5,"rt":"organic","cr":""},{"id":"1396082091","pos":6,"rt":"organic","cr":""},{"id":"1212857112","pos":7,"rt":"organic","cr":'
# b'""},{"id":"1391074652","pos":8,"rt":"organic","cr":""},{"id":"1402514059","pos":9,"rt":"organic","cr":""},{"id":"1348221026","po'
# b's":10,"rt":"organic","cr":""},{"id":"unfilled","pos":11,"rt":"partner_ebay","cr":""}]},"ts":"2019-01-24 18:30:33.377+0000"}];\n  '
# b"  (function (w, d, s, l, i) {\n    w[l] = w[l] || [];\n    w[l].push({'gtm.start': new Date().getTime(), event: 'gtm.js'});\n    va"
# b"r f = d.getElementsByTagName(s)[0],\n            j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';\n    j.async = tr"
# b"ue;\n    j.src =\n            '//www.googletagmanager.com/gtm.js?id=' + i + dl;\n    f.parentNode.insertBefore(j, f);\n})(window, do"
# b'cument, \'script\', \'dataLayer\', \'GTM-W4V6\');\n</script>\n<!-- End Google Tag Manager --><script src="https://kijiji-ca.videoplayerh'
# b'ub.com/gallery-1-11-4-kijiji.js" integrity="sha384-3OWAk6EGlsbQILqFbIlFtvxPK8yN7xluKeyOyhmAHCSN6pgF5bZzvJBPAn0JcRNa" crossorigin'
# b'="anonymous"></script>\n<script async="async" src="https://www.google.com/adsense/search/ads.js"></script>\n<script type="text/jav'
# b'ascript" charset="utf-8">\n    (function(G,o,O,g,L,e){G[g]=G[g]||function(){(G[g][\'q\']=G[g][\'q\']||[]).push(\n    arguments)},G[g]['
# b'\'t\']=1*new Date})(window,document,\'script\',\'_googCsa\');\n</script>\n<script src="https://ca.classistatic.com/static/V/7738/js/thir'
# b'd-party/aam-dil-v6.12.js"></script>\n<script>\n    var dataAAM = dataAAM || {};\n    var kijijiDil = DIL.create({\n        partner: '
# b"'kijiji',\n        uuidCookie: { name: 'aam_uuid', days: 30 }\n    });\n\n    \n    gptAdTargeting.forEach(function(targeting) {\n    "
# b"    dataAAM[targeting.key] = targeting.value;\n    });\n\n    \n    kijijiDil.api.signals(dataAAM, 'c_').submit();\n</script>\n<link r"
# b'el="alternate" type="application/rss+xml" href="/rss-srp-tool/city-of-toronto/carpenter-tools/k0c110l1700273"/>\n    <!-- Sunset '
# b'banner for leq IE 10 -->\n    <script defer type="text/javascript">\n        $(document).ready(function() {\n            if(documen'
# b't.all) {\n                $(\'#MainContainer\').prepend("<div id=\\"IeSunset\\">" +\n                    "<h3>Your browser is out of d'
# b'ate. Change to a modern browser for a more secure web experience.</h3><ul>" +\n                    "<li class=\\"moz\\"><a href=\\"h'
# b'ttps://www.mozilla.org/en-US/firefox/new/\\" target=\\"_blank\\" rel=\\"noopener noreferrer\\"><h4>Mozilla Firefox <span>Download Her'
# b'e</span></h4></a></li>" +\n                    "<li class=\\"chrome\\"><a href=\\"https://www.google.com/chrome/browser/desktop/\\" t'
# b'arget=\\"_blank\\" rel=\\"noopener noreferrer\\"><h4>Google Chrome<span>Download Here</span></h4></a></li>" +\n                    "<'
# b'li class=\\"ie\\"><a href=\\"https://support.microsoft.com/en-ca/help/17621/internet-explorer-downloads\\" target=\\"_blank\\" rel=\\"n'
# b'oopener noreferrer\\"><h4>Internet Explorer<span>Download Here</span></h4></a></li>" +\n                    "</ul></div>");\n      '
# b'      }\n        });\n    </script>\n</head>\n\n<body id="PageSRP"\n      class="responsive responsive-dp en"\n>\n\n\n    <div id="FesLoad'
# b'erTop">\n      <script> window.baseUrl="//ca.classistatic.com/service-static/frontend-service"; </script>\n      <script> window.b'
# b'oxUrl="//www.kijiji.ca/"; </script>\n    </div>\n  <script type="text/javascript" src="https://ca.classistatic.com/static/V/7738/j'
# b's/text/text.js"></script>\n\n<form style="display:none">\n        <input type="hidden" name="query" id="AdsenseQuery" value="carpen'
# b'ter tools  City of Toronto Toronto (GTA) buy and sell tools" />\n        <input type="hidden" name="query" id="AdsenseQueryShop" '
# b'value="carpenter tools  tools" />\n    </form>\n<script type="text/javascript" src="https://ca.classistatic.com/static/V/7738/js/t'
# b'ext/afs.js"></script>\n<script type="text/javascript">\n    Kj.Sponsors.init({\n        maxAds: 6,\n        keepTopBar: true\n    });'
# b"\n\n    \n        var clientIdShop = 'vert-pla-kijiji-ca-srp';\n        var adsenseConfig = {\n            test: 'off',\n            l"
# b"anguage: 'en',\n            pageType: 'srp',\n            csa: {\n                top: {\n                    number: 1\n            "
# b'    },\n                bottom: {\n                    number: 3\n                },\n                page: 1,\n                repea'
# b"ts: 1,\n                clientId: 'kijiji-ca-search2',\n                clientIdShop: clientIdShop,\n                query: 'carpen"
# b"ter tools  City of Toronto Toronto (GTA) buy and sell tools',\n                channel: '0_w_srl_10_110_x_1_o_x+kijiji_ca_afs_007"
# b'+1_w_x_x_x_x_x_x_kca26723_b+1_w_x_x_x_x_x_x_kca28709_b+1_w_x_x_x_x_x_x_kca29068_b+1_w_x_x_x_x_x_x_kca28833_a+1_w_x_x_x_x_x_x_kca'
# b"23868_a+1_w_x_x_x_x_x_x_kca29114_f',\n                width: '100%',\n                isLargeImage: true\n            }\n        };\n"
# b"\n        \n                adsenseConfig.csa.settingsId = 'be02b44a0a483a849aeace2e92144290';\n            \n\n            Kj.AFSh.i"
# b'nit(adsenseConfig);\n        \n\n        Kj.Adsense.init(adsenseConfig);\n        Kj.Sponsors.chain(Kj.Adsense.api);\n\n    </script>\n'
# b'<script type="text/javascript">\n    var pageTrackingIdentifier = \'Search Results Page\';\n    var gaEventLabel = \'L1Cat=Buy & Sell'
# b';L2Cat=Tools;L1Location=Canada;L2Location=Toronto (GTA);L3Location=City of Toronto\';\n</script><script defer src="https://ca.clas'
# b'sistatic.com/static/V/7738/js/sponsors/ads/ads.js"></script>\n<div id="MainContainer">\n    \n        <div class="fes-pagelet">\n   '
# b'       <div data-fes-id="header"><header class="headerElement-3349737891" role="banner" data-reactroot=""><a class="skipToMain-3'
# b'679500748 button-1997310527 button__primary-1681489609 button__medium-1066667140" rel=" noopener noreferrer" href="#mainPageCont'
# b'ent">Skip to main content</a><div class="printLogo-4110822992"><div class="logo-3282416437" style="visibility:hidden"><a class="'
# b'logoLink-1425315727" href="/" title="Kijiji"><svg aria-labelledby="kijiji-logo-title" class="icon-459822882 logoLinkIcon-6813363'
# b'7" focusable="false" height="100%" role="img" width="100%"><title id="kijiji-logo-title">Kijiji</title><use xlink:href="#kijiji-'
# b'logo"></use></svg><svg aria-labelledby="kijiji-logo-mobile-title" class="icon-459822882 logoLinkIconMobile-3507558487" focusable'
# b'="false" height="100%" role="img" width="100%"><title id="kijiji-logo-mobile-title">Kijiji</title><use xlink:href="#kijiji-logo-'
# b'mobile"></use></svg></a></div></div><div class="overlay-1946744954"></div><div class="headerContainer-1051376346"><div class="lo'
# b'goBarWrapper-2331155591"><div class="logoBar-2615648661"><div class="logo-3282416437" style="visibility:hidden"><a class="logoLi'
# b'nk-1425315727" href="/" title="Kijiji"><svg aria-labelledby="kijiji-logo-title" class="icon-459822882 logoLinkIcon-68133637" foc'
# b'usable="false" height="100%" role="img" width="100%"><title id="kijiji-logo-title">Kijiji</title><use xlink:href="#kijiji-logo">'
# b'</use></svg><svg aria-labelledby="kijiji-logo-mobile-title" class="icon-459822882 logoLinkIconMobile-3507558487" focusable="fals'
# b'e" height="100%" role="img" width="100%"><title id="kijiji-logo-mobile-title">Kijiji</title><use xlink:href="#kijiji-logo-mobile'
# b'"></use></svg></a></div><div class="headerTools-2066608048"><div class="headerButtons-1611810662"><a href="/?siteLocale=fr_CA" c'
# b'lass="headerLinkLanguage-2414279999" rel="nofollow" title="Fran\xc3\xa7ais" data-qa-id="language-toggle">fr</a><div class="headerButto'
# b'n-645881860"><a class="headerButtonIconLink-558717184" data-qa-id="header-link-my-messages" rel="nofollow noopener noreferrer" h'
# b'ref="/m-msg-my-messages/" title="My Messages"><svg class="icon-459822882" focusable="false" height="100%" role="img" width="100%'
# b'"><use xlink:href="#icon-messages"></use></svg><div class="messagesUnreadCount-1239728541"></div></a></div><div class="root-2862'
# b'412925"><div class="root-3687532350"><a href="/t-user-registration.html?targetUrl=L2ItY2l0eS1vZi10b3JvbnRvL2NhcnBlbnRlci10b29scy'
# b'9rMGwxNzAwMjczP2RjPXRydWVeNlNRalRsV25BWnd3cFFXWEVoaXpUUT09" class="link-2454463992 register-4281208362" rel="nofollow" title="Re'
# b'gister">Register</a><span class="or-4281208362">\xc2\xa0<!-- -->or<!-- -->\xc2\xa0</span><a href="/t-login.html?targetUrl=L2ItY2l0eS1vZi10b3'
# b'JvbnRvL2NhcnBlbnRlci10b29scy9rMGwxNzAwMjczP2RjPXRydWVeNlNRalRsV25BWnd3cFFXWEVoaXpUUT09" class="link-2454463992" rel="nofollow" t'
# b'itle="Sign In">Sign In</a></div></div><a class="headerButtonPostAd-2493039301" rel="nofollow noopener noreferrer" data-qa-id="he'
# b'ader-link-post-ad" href="/p-select-category.html" title="Post ad">Post ad</a></div></div></div></div><div class="searchBarWrappe'
# b'r-3128709573"><form class="searchBar-2782911640" action="/b-search.html"><input type="hidden" name="formSubmit" value="true"/><i'
# b'nput type="hidden" name="adIdRemoved" value=""/><input type="hidden" name="adPriceType" value=""/><input type="hidden" name="bra'
# b'nd" value=""/><input type="hidden" name="carproofOnly" value="false"/><input type="hidden" name="categoryId" value="110"/><input'
# b' type="hidden" name="categoryName" value="Tools"/><input type="hidden" name="cpoOnly" value="false"/><input type="hidden" name="'
# b'dc" value="true"/><input type="hidden" name="gpTopAd" value="false"/><input type="hidden" name="highlightOnly" value="false"/><i'
# b'nput type="hidden" name="ll" value=""/><input type="hidden" name="locationId" value="1700273"/><input type="hidden" name="minPri'
# b'ce" value=""/><input type="hidden" name="maxPrice" value=""/><input type="hidden" name="origin" value=""/><input type="hidden" n'
# b'ame="pageNumber" value="1"/><input type="hidden" name="searchView" value="LIST"/><input type="hidden" name="sortByName" value="d'
# b'ateDesc"/><input type="hidden" name="userId" value=""/><input type="hidden" name="urgentOnly" value="false"/><div class="formFie'
# b'ldKeyword-2703177926"><label class="searchLabel-4229750769" for="SearchKeyword">Search</label><input type="text" class="inputKey'
# b'word-3692124783" data-qa-id="header-field-keyword" id="SearchKeyword" name="keywords" placeholder="Search for anything..." autoC'
# b'omplete="off" value="carpenter tools"/><div></div></div><div class="formFieldCategory-3432574170"><label class="searchLabel-4229'
# b'750769" for="SearchCategory">Categories</label><select class="selectCategory-1116892437" id="SearchCategory" name="SearchCategor'
# b'y"><option value="0">All Ads</option><option value="10">Buy &amp; Sell</option><option value="72">Services</option><option value'
# b'="27">Cars &amp; Vehicles</option><option value="112">Pets</option><option value="800">Vacation Rentals</option><option value="1'
# b'">Community</option><option value="34">Real Estate</option><option value="45">Jobs</option><option selected="" value="110">Tools'
# b'</option></select><svg class="icon-459822882 selectCategoryIcon-2749838590" focusable="false" height="100%" role="img" width="10'
# b'0%"><use xlink:href="#icon-dropdown"></use></svg></div><div class="formFieldLocationPicker-346936782"><label class="searchLabel-'
# b'4229750769" for="SearchLocationPicker">Location</label><input type="text" class="inputLocationPicker-3519965181" id="SearchLocat'
# b'ionPicker" name="SearchLocationPicker" placeholder="Select location..." value="" readonly=""/><svg class="icon-459822882 inputLo'
# b'cationPickerIcon-522011117" focusable="false" height="100%" role="img" width="100%"><use xlink:href="#icon-dropdown"></use></svg'
# b'><div class="locationListContainer-3905147260"></div></div><button class="searchSubmit-2947444568" data-qa-id="header-button-sub'
# b'mit" name="SearchSubmit" type="submit" title="Find what you are looking for"><svg aria-labelledby="icon-myadssearch-title" class'
# b'="icon-459822882 searchSubmitIcon-2062811939" focusable="false" height="100%" role="img" width="100%"><title id="icon-myadssearc'
# b'h-title">Find what you are looking for</title><use xlink:href="#icon-myadssearch"></use></svg><span class="searchSubmitText-3139'
# b'797413">Find what you are looking for</span></button></form></div></div></header></div>\n          <script type="text/javascript"'
# b'>if(rehydrate===undefined){var rehydrate={};}rehydrate["header"]={componentPath:"Shared/Header/Header",props:{}};</script>\n     '
# b'   </div>\n      <ul class="more-searches">\n            <li>\n                Related:</li>\n            <li>\n                    <'
# b'a class="related-search" href="/b-tool/city-of-toronto/tools/k0c110l1700273">\n                        tools</a>\n                '
# b'</li>\n            <li>\n                    <a class="related-search" href="/b-tool/city-of-toronto/carpenter/k0c110l1700273">\n  '
# b'                      carpenter</a>\n                </li>\n            <li>\n                    <a class="related-search" href="/'
# b'b-tool/city-of-toronto/dewalt/k0c110l1700273">\n                        dewalt</a>\n                </li>\n            <li>\n       '
# b'             <a class="related-search" href="/b-tool/city-of-toronto/antique-tools/k0c110l1700273">\n                        anti'
# b'que tools</a>\n                </li>\n            <li>\n                    <a class="related-search" href="/b-tool/city-of-toronto'
# b'/tool-box/k0c110l1700273">\n                        tool box</a>\n                </li>\n            <li>\n                    <a cl'
# b'ass="related-search" href="/b-tool/city-of-toronto/tool-pouch/k0c110l1700273">\n                        tool pouch</a>\n          '
# b'      </li>\n            <li>\n                    <a class="related-search" href="/b-tool/city-of-toronto/router/k0c110l1700273">'
# b'\n                        router</a>\n                </li>\n            <li>\n                    <a class="related-search" href="/'
# b'b-tool/city-of-toronto/woodworking-tools/k0c110l1700273">\n                        woodworking tools</a>\n                </li>\n  '
# b'          <li>\n                    <a class="related-search" href="/b-tool/city-of-toronto/tool/k0c110l1700273">\n               '
# b'         tool</a>\n                </li>\n            <li>\n                    <a class="related-search" href="/b-tool/city-of-tor'
# b'onto/tool-chest/k0c110l1700273">\n                        tool chest</a>\n                </li>\n            </ul><div id="MessageC'
# b'ontainer">\n        </div>\n\n    <div id="mainPageContent" tabindex="-1">\n        \n        <div class="fes-pagelet">\n          <di'
# b'v data-fes-id="alertPrompt"><div class="alertPromptContainer-3625631897" data-reactroot=""><span></span></div></div>\n          <'
# b'script type="text/javascript">if(rehydrate===undefined){var rehydrate={};}rehydrate["alertPrompt"]={componentPath:"Alerts/AlertP'
# b'rompt",props:{"isEmptyResult":false,"keywords":"carpenter tools","isLastPage":true,"userEmail":null}};</script>\n        </div>\n '
# b'     <div class="layout-0 breadcrumbLayout clearfix">\n        <h2 class="icon-link srp-top">\n            <div class="icon cat-po'
# b'st"></div>\n            <a href="/p-select-category.html?categoryId=110" class="post-ad-begin" data-btn-loc="srp-top" rel="nofoll'
# b'ow">Post an Ad in this category</a>\n        </h2>\n\n        <div class="breadcrumb">\n            <span itemscope="" itemtype="htt'
# b'p://data-vocabulary.org/Breadcrumb">\n                        <a href="https://www.kijiji.ca/h-ontario/9004"\n                    '
# b'       itemprop="url" class="location-selected location-hp" data-id="1700273"><span itemprop="title">Ontario</span></a>\n        '
# b'            </span>\n                     &gt; <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">\n             '
# b'           <a href="https://www.kijiji.ca/h-gta-greater-toronto-area/1700272"\n                           itemprop="url" class="l'
# b'ocation-selected location-hp" data-id="1700273"><span itemprop="title">Toronto (GTA)</span></a>\n                    </span>\n    '
# b'                 &gt; <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">\n                        <a href="http'
# b's://www.kijiji.ca/h-city-of-toronto/1700273"\n                           itemprop="url" class="location-selected location-hp" dat'
# b'a-id="1700273"><span itemprop="title">City of Toronto</span></a>\n                    </span>\n                     &gt; <span ite'
# b'mscope="" itemtype="http://data-vocabulary.org/Breadcrumb">\n                        <a href="https://www.kijiji.ca/b-buy-sell/ci'
# b'ty-of-toronto/carpenter-tools/k0c10l1700273"\n                           itemprop="url" class="category-selected" data-id="10"><s'
# b'pan itemprop="title">Buy &amp; Sell</span></a>\n                    </span>\n                     &gt; <span itemscope="" itemtype'
# b'="http://data-vocabulary.org/Breadcrumb">\n                        <a href="https://www.kijiji.ca/b-tool/city-of-toronto/carpente'
# b'r-tools/k0c110l1700273"\n                           itemprop="url" class="category-selected" data-id="110"><span itemprop="title"'
# b'>Tools</span></a>\n                    </span>\n                     &gt; <span><h1>"carpenter tools" in Tools in City of Toronto<'
# b'/h1></span>\n                    </div>\n\n        <div class="centered-item">\n                <div class="outerWrapper">\n         '
# b'           <div id="StickyLeaderboard" class="leaderboardContainer">\n                        <div id="gpt-leaderboard-top" class'
# b'="banner leaderboard top ad-leader-top breakpoint-750-hide">\n    <script>\n    googletag.cmd.push(function () {\n        googletag'
# b".display('gpt-leaderboard-top');\n    });\n    </script>\n</div>\n\n</div>\n                </div>\n            </div>\n        </div>\n\n"
# b'    <div class="layout-3">\n    <div class="col-1">\n        <div class="container-primary srp-navigation">\n    <header id="Curren'
# b'tResultsPageTipTrigger" class="page-tip-trigger" data-content="KijijiAlertTooltip">\n        <strong class="rsp-current-matches">'
# b'Current Matches</strong>\n        <strong class="rsp-filter-results">Filter Results</strong>\n        &nbsp;<span class="titlecoun'
# b't">(9)</span>\n    </header>\n    <div class="content">\n\n        <h3>Category:</h3>\n            <ul>\n                <li>\n        '
# b'    <a href="/b-city-of-toronto/carpenter-tools/k0l1700273" class="category-selected" data-id="0 ">\n                All Categori'
# b'es</a>\n            </li>\n    <ul >\n        <li>\n            <a href="/b-buy-sell/city-of-toronto/carpenter-tools/k0c10l1700273" '
# b'class="category-selected" data-id="10 "data-event="ChangeCategory">\n                Buy & Sell</a>\n            </li>\n    <ul >\n '
# b'       <li class="highlight">\n            <a href="/b-buy-sell/city-of-toronto/carpenter-tools/k0c10l1700273">&times;</a>\n      '
# b'      Tools (9)</li>\n    <ul >\n        <li>\n            <a href="/b-power-tool/city-of-toronto/carpenter-tools/k0c703l1700273" c'
# b'lass="category-selected" data-id="703 "data-event="ChangeCategory">\n                Power Tools</a>\n             (3)</li>\n    <l'
# b'i>\n            <a href="/b-tool-other/city-of-toronto/carpenter-tools/k0c715l1700273" class="category-selected" data-id="715 "da'
# b'ta-event="ChangeCategory">\n                Other</a>\n             (3)</li>\n    <li>\n            <a href="/b-tool-storage-bench/c'
# b'ity-of-toronto/carpenter-tools/k0c704l1700273" class="category-selected" data-id="704 "data-event="ChangeCategory">\n            '
# b'    Tool Storage & Benches</a>\n             (2)</li>\n    <li>\n            <a href="/b-hand-tool/city-of-toronto/carpenter-tools/'
# b'k0c702l1700273" class="category-selected" data-id="702 "data-event="ChangeCategory">\n                Hand Tools</a>\n            '
# b' (1)</li>\n    </ul>\n</ul>\n</ul>\n</ul>\n        <hr>\n                <h3>Location:</h3>\n                <ul>\n                    <'
# b'ul >\n        <li>\n            <a href="/b-tool/ontario/carpenter-tools/k0c110l9004" class="location-selected" data-id="9004 "dat'
# b'a-event="ChangeLocation">\n                Ontario</a>\n            </li>\n    <ul >\n        <li>\n            <a href="/b-tool/gta-'
# b'greater-toronto-area/carpenter-tools/k0c110l1700272" class="location-selected" data-id="1700272 "data-event="ChangeLocation">\n  '
# b'              Toronto (GTA)</a>\n            </li>\n    <ul >\n        <li class="highlight">\n            <a href="/b-tool/gta-grea'
# b'ter-toronto-area/carpenter-tools/k0c110l1700272">&times;</a>\n            City of Toronto (7)</li>\n    </ul>\n</ul>\n</ul>\n</ul>\n  '
# b'          <hr>\n                <h3>Distance&nbsp;\n                    <span class="tooltip-trigger" id="DistanceToolTipButton" d'
# ...
# b'kes":{"failure":false,"pending":false,"success":false},"models":{"failure":false,"pending":false,"success":false},"inventory":{"'
# b'failure":false,"pending":false,"success":false}},"makes":[],"models":[],"inventoryCount":null},"config":{"toggleHomepageFeed":fa'
# b'lse,"requestUrl":"\\u002Fb-city-of-toronto\\u002Fcarpenter-tools\\u002Fk0l1700273","showAdmarktLink":false,"toggleAlertsForcedLogin'
# b'":false,"clientType":{"isTablet":false,"isMobile":false,"isDesktop":true,"device":"UNKNOWN (mobile=false, isApple=false)"},"boxI'
# b'nternalUrl":"\\u002Fb-search.html","toggleMoveCrossPromotion":true,"requestQueryString":"dc=true","changeLocationURL":"\\u002Fb-ch'
# b'ange-location.html?newLocationId=","searchForm":{"attributeMap":{},"ll":null,"highlightOnly":false,"sortByName":"dateDesc","adPr'
# b'iceType":null,"adIdRemoved":null,"maxPrice":null,"attributeFiltersMax":{},"userId":null,"origin":null,"categoryName":"Tools","ke'
# b'ywords":"carpenter tools","searchView":"LIST","urgentOnly":false,"cpoOnly":false,"gpTopAd":false,"locationId":1700273,"radius":"'
# b'","attributeFiltersMin":{},"parentCategoryName":"Buy & Sell","address":"City of Toronto, Ontario","noLocation":false,"minPrice":'
# b'null,"pageNumber":1,"categoryId":110,"locationPath":"0,9004,1700272,1700273","parentCategorySeoUrl":"\\u002Fb-buy-sell\\u002Fcity-'
# b'of-toronto\\u002Fc10l1700273","carproofOnly":false,"dc":true},"toggleCarproofRebrand":true,"boxInternalQueryString":"keywords=car'
# b'penter+tools&locationId=1700273&siteLocale=en_CA","userLoggedIn":false,"hashedUserId":null,"toggleProfileReplyRate":false,"toggl'
# b'eMoveCrossPromoInCategorySuggestions":false,"language":"en","toggleRadialSearch":false,"targetUrl":"L2ItY2l0eS1vZi10b3JvbnRvL2Nh'
# b'cnBlbnRlci10b29scy9rMGwxNzAwMjczP2RjPXRydWVeNlNRalRsV25BWnd3cFFXWEVoaXpUUT09","toggleMoveXpromoAutosLandingPage":false},"locatio'
# b'nPicker":{},"postAd":{"categories":{"all":{"level1":{"items":[],"parentId":null},"level2":{"items":[],"parentId":null},"level3":'
# b'{"items":[],"parentId":null}},"suggested":[],"submittedTitle":""},"packages":{"error":false,"frozen":true,"items":{},"loaded":fa'
# b'lse,"selected":null},"postAdData":{"editing":false,"insertionFee":{"disclaimer":null,"exists":null,"postingLimit":null,"price":n'
# b'ull},"l1CategoryId":null,"isShoppingCart":false,"isRepost":false},"postingLimit":{"adLimit":null,"categoryId":null,"categoryName'
# b'":"","isAdmarktCategory":null,"isAdmarktUser":null,"isNewAd":null},"categoryConfig":[],"location":{"savedLocation":null,"posting'
# b'Location":null,"showExactLocation":true,"editingLocation":false,"locationApiLoadFailed":false},"loading":{"categories":{"all":{"'
# b'failure":false,"pending":false,"success":false},"suggested":{"failure":false,"pending":false,"success":false}},"postAdData":{"fa'
# b'ilure":false,"pending":false,"success":false},"categoryConfig":{"failure":false,"pending":false,"success":false},"location":{"fa'
# b'ilure":false,"pending":false,"success":false}}},"messageBox":{"unreadCount":{"total":0,"asPoster":0,"asReplier":0},"loaded":fals'
# b'e,"banners":{},"deleting":false,"activeConversation":{"loading":false,"loaded":false,"blockLoading":false,"failed":false,"data":'
# b'{}},"totalCount":0,"prefetching":false,"roleFilter":"All","conversations":[],"unseenNotificationCount":0,"pageNum":0,"selected":'
# b'[],"loading":false,"allSelected":false,"failed":false,"conversationCache":[]},"homepageGallery":{"ads":[],"firstLoad":true,"load'
# b'ing":false,"loaded":false},"recentlyViewedAds":{"loading":{"failure":false,"pending":false,"success":false},"ads":[]},"ebaySpons'
# b'or":{"ads":[],"loading":false,"loaded":false},"viewItemPage":{"loading":false,"loaded":false,"viewItemData":{},"isModalMapOpen":'
# b'false},"banners":{"rendered":{}},"myKijiji":{"myAds":{"ads":{"adsDirectory":{},"sortedAdIds":[],"requestedAds":{},"filtering":{"'
# b'activeFilter":"active","currentSort":{"active":{"field":"sortableEndDate","ascending":true},"inactive":{"field":"sortableEndDate'
# b'","ascending":true}},"search":""},"currentPage":1,"overheadMessageError":null},"promotions":{"totalPrice":0,"selectedfeatureIds"'
# b':[],"sellingPoint":"MY_KIJIJI"},"loading":{"fullAds":{"failure":false,"pending":false,"success":false},"requestedAds":{"failure"'
# b':false,"pending":false,"success":false},"sparseAds":{"failure":false,"pending":false,"success":false}}},"priceDrop":{"oldPrice":'
# b'0,"userId":0,"error":false,"newPrice":0,"featureDuration":0,"successPage":"","featurePrice":0,"spawnId":0,"attemptingPurchase":f'
# b'alse,"failurePage":"","featureIdentifier":""},"surveys":{"loading":{"failure":false,"pending":false,"success":false}}},"profile"'
# b':{"loading":false,"loaded":false},"router":{"route":"UNKNOWN","pathParams":{},"queryParams":{"dc":"true"},"isVirtualPageView":fa'
# b'lse},"messages":{},"componentPositions":{"componentOffsets":{}},"searchResults":{"hasDealerRatings":false,"hasSponsors":false,"l'
# b'oadStates":{"ratings":{"loaded":false,"loading":false},"sponsors":{"loaded":false,"loading":false}},"loaded":false,"loading":fal'
# b'se},"mediaGallery":{},"homepage":{"loading":false,"loaded":false,"data":{},"searchFieldFocused":false},"cookies":{},"showMore":{'
# b'},"admarktTopSpot":{},"r2s":{"submitted":false,"submitting":false,"expanded":false,"expandedByUser":false,"error":null},"itemLoc'
# b'ationMap":{},"recommendedAds":{"ads":[],"loaded":false,"loading":false},"alertsModal":{"submitting":false},"reportAd":{"submitti'
# b'ng":false,"submitted":false},"financing":{"submitting":false,"submitted":false},"phoneNumber":{"value":null},"googleMapApi":{"lo'
# b'cationApiLoadFailed":false},"shareLink":{"adInfo":{},"loaded":false,"loading":false},"locale":"en-CA","dealerRatings":{"loading"'
# b':false,"loaded":false,"mobialsData":{}},"categoryMenu":{"categories":[],"loaded":false,"loading":false},"pubnub":{"connected":fa'
# b'lse,"suspended":false,"reconnectAllowed":true},"carproofRequest":{"requestAttempt":false,"requestSuccess":false,"requestFail":fa'
# b'lse,"requestMessage":null}};</script>\n      <script defer src="//ca.classistatic.com/service-static/frontend-service/runtime.bf1'
# b'76b67.js"></script>\n<script defer src="//ca.classistatic.com/service-static/frontend-service/vendor.de954107.js"></script>\n<scri'
# b'pt defer src="//ca.classistatic.com/service-static/frontend-service/app.7d1b819a.js"></script>\n<script defer src="//ca.classista'
# b'tic.com/service-static/frontend-service/ebaySponsor.a7388f8e.js"></script>\n<script defer src="//ca.classistatic.com/service-stat'
# b'ic/frontend-service/searchResults.9588eb8e.js"></script>\n<script defer src="//ca.classistatic.com/service-static/frontend-servic'
# b'e/alertPrompt.fc739c9b.js"></script>\n<script defer src="//ca.classistatic.com/service-static/frontend-service/footer.42dd630f.js'
# b'"></script>\n<script defer src="//ca.classistatic.com/service-static/frontend-service/header.a9fab8ed.js"></script>\n<script defer'
# b' src="//ca.classistatic.com/service-static/frontend-service/en-i18n-json.b230d604.js"></script>\n<script defer src="//ca.classist'
# b'atic.com/service-static/frontend-service/styles.f604c49d.js"></script>\n<script defer src="//ca.classistatic.com/service-static/f'
# b'rontend-service/svg.f37dae65.js"></script>\n    </div>\n  <script type="text/javascript">window.__apolloData={"$ROOT_QUERY.suggest'
# b'Keyword":{"query":"","categoryId":0,"selected":false,"__typename":"SuggestKeyword"},"ROOT_QUERY":{"suggestKeyword":{"type":"id",'
# b'"generated":true,"id":"$ROOT_QUERY.suggestKeyword","typename":"SuggestKeyword"},"__typename":"GeolocationQuery","geolocation":{"'
# b'type":"id","generated":true,"id":"$ROOT_QUERY.geolocation","typename":"Geolocation"}},"$ROOT_QUERY.geolocation":{"geolocation":n'
# b'ull,"geolocationError":false,"__typename":"Geolocation"}};</script><script src="https://ca.classistatic.com/static/V/7738/js/pag'
# b'es/cguid.js"></script>\n<script src="https://ca.classistatic.com/static/V/7738/js/common.js"></script>\n\n<!-- BUNDLE: _ --><!-- EN'
# b'D BUNDLE: _ -->\n<!-- BUNDLE: gpt --><!-- END BUNDLE: gpt -->\n<script type="text/javascript" defer src="https://ca.classistatic.c'
# b'om/static/V/7738/js/legacy-page-controllers/watchlistPanel.js"></script>\n\n<div id="WatchlistContainer">\n        <header>\n       '
# b'     <div class="watchlist-star-small"></div>\n            <h3>My Favourites (<span id="WatchListCount"></span>)</h3>\n           '
# b' <div class="watchlist-tab-arrow"></div>\n        </header>\n        <div class="body">\n            <div class="content">\n        '
# b'        <div class="title">Recently Added:</div>\n                <div class="view-all">\n                    <a href="/m-watch-li'
# b'st.html">View all</a>\n                </div>\n                <div id="Watchlist">\n                    <ul id="WatchlistItems">\n '
# b'                   </ul>\n                </div>\n            </div>\n        </div>\n    </div>\n<script type="text/javascript" src='
# b'"https://ca.classistatic.com/static/V/7738/js/srp.js"></script>\n            <script type="text/javascript" src="https://ca.class'
# b'istatic.com/static/V/7738/js/common/third-party.js"></script>\n            <script defer src=\'https://ca.classistatic.com/static/'
# b'V/7738/js/templates.js\'></script>\n\n<script type="text/javascript">\n    $(document).ready(function () {\n        var data = window'
# b'.dataLayer ? dataLayer[0] : [];\n        Zoop.init({\n            data: {dl: data},\n            config: {\n                url: "/j'
# b'-page-view.json",\n                token: "1548354633104.d5818c1145415671b7ae4cb0f308194e5cb73bced5eb37e55350960853f844c5"\n      '
# b'      }\n        });\n        Zoop.callEvent({\n            data: {}\n        });\n    });\n</script>\n<script type="text/javascript">\n'
# b'    Kj.extVars = {\n        validationMessages : {\n            group : "Please correct the errors below:",\n            req : "Ple'
# b'ase enter information above.",\n            email : "Please enter a valid email address.",\n            number : "Please enter a v'
# b'alid number.",\n            phone: "Please provide a valid phone number.",\n            maxlength : "Sorry, our limit is {{max}} c'
# b'haracters. Please shorten your message.",\n            minlength: "Input needs to be at least {{min}} characters.",\n            n'
# b'umberRange: "Please enter a value between {{min}} and {{max}}.",\n            numberMax: "Please enter a value no greater than {{'
# b'max}}.",\n            numberMin: "Please enter a value of at least {{min}}.",\n            fileType: "One or more image(s) failed '
# b'to upload. File format not supported.",\n            fileSize: "One or more image(s) failed to upload. File size limit exceeded."'
# b',\n            matching: "Input does not match above",\n            headline: "Please correct the following before continuing:",\n '
# b'           creditcard: "Please correct your credit card number.",\n            radioButton: "Please select option above.",\n      '
# b'      postalCode: "Please provide a valid Postal Code.",\n            websiteUrl: "Website URL is invalid, please check your inpu'
# b't."\n        },\n        tracking : {\n            page: "Search Results Page",\n            locId: "1700273",\n            catId: "1'
# b'10",\n            adOrUserNotFound: false\n        },\n        domainUrl : ".kijiji.ca",\n        locale: "en_CA",\n        facebook:'
# b' {\n            requiredPermissions: "We require permission to access your email address, please try again with the correct permi'
# b'ssions.",\n            error: "An error has occurred with Facebook login. Please try again."\n        },\n        isTestEnvironment'
# b': false,\n        staticUrl: "https://ca.classistatic.com/static/V/7738/"\n        \n    };\n\n    $(document).ready(function() {\n\n  '
# b'      \n        Kj.Tracking.initTrackAttributeSelection();\n        Kj.Tracking.initTrackPostAdBeginButtons();\n        Kj.Tracking'
# b'.initTrackUserAccountActions({\n            isDealer: false\n        });\n        Kj.Tracking.initTrackAdActivation();\n        Kj.T'
# b'racking.TrackHelpDesk.init();\n        Kj.Tracking.initAddLinkerParam();\n        Kj.initHoverButtons();\n        Kj.initToggleButt'
# b'ons();\n        Kj.initCollapseCategories();\n        Kj.initHistoryBackLink();\n        Kj.Banners.BannerRendered.init();\n        '
# b'Kj.initPrintLinks();\n        Kj.initAdChoice();\n        \n            Kj.Banners.AdBlock.init();\n        \n        Belen.Controlle'
# b"r.Search.extVars = {\n            staticContentBaseUrl: 'https://ca.classistatic.com/static/V/7738',\n            editWatchlistAja"
# b"xUrl: '/j-edit-watchlist.json',\n            getWatchlistEntryAjaxUrl: '/j-get-watchlist-item.json',\n            watchlistTitleAd"
# b"d: 'Click to add to My Favourites',\n            watchlistTitleRemove: 'Saved to My Favourites'\n        };\n        Belen.Controll"
# b"er.Search.Watchlist.init();\n\n        //Check for undefined override.\n        if (typeof undefined !== 'undefined') {\n           "
# b' console.warn(\'HEY! Something is overwriting `undefined`. Don\\\'t ship!\');\n        }\n    });\n</script>\n\n<script type="text/javasc'
# b'ript" src="//pulsar.ebay.com/plsr/mpe/0/KIJI/9?pld=%5B%7B%22plsUBT%22%3A1%2C%22ea%22%3A%22VIEW%22%2C%22pge%22%3A2351445%2C%22app'
# b'%22%3A%22KijijiApp%22%7D%5D&getCGuid=1&cache=0.24303798959590495&callback=pulsarCallback"></script>\n\n<noscript>\n    <style>\n    '
# b'    .jsonly {\n            display: none;\n        }\n        .jshidden {\n            display: block;\n        }\n    </style>\n    <i'
# b'frame src="//www.googletagmanager.com/ns.html?id=GTM-W4V6"\n            height="0" width="0" style="display:none;visibility:hidde'
# b'n"></iframe>\n</noscript>\n<script type="text/javascript">\n    $(document).ready(function() {\n\n        \n            Kj.Tracking.tr'
# b'ackGAEvent({\n                action: "TopSpotLoaded",\n                label: "numResults=0;"\n            });\n        \n        Kj'
# b'.extVars.search = {\n            page: 1,\n            hasKeywords: true,\n            suid: Math.round(Math.random() * 10000000000'
# b'000).toString(36) // TODO: Fake search CID, backend to inject real one.\n        };\n        Kj.Search.initDistanceSlider({\n      '
# b"      distanceLabel : 'Drag Me',\n            distanceMax : 500,\n            radius : '100',\n            address : 'City of Toron"
# b"to'\n        });\n        \n            if ($('.zero-results').length == 0) {\n                Kj.Search.initStickyScyscraper();\n   "
# b'             Kj.Search.initStickyLeaderboard();\n            }\n        \n        Kj.initToolTips();\n        Kj.Search.initSearchFi'
# b"lters();\n        Kj.Listings.initAlertSubscribe({\n            emailAlertSubscribeUrl: '/j-subscribe-alerts.json',\n            ke"
# b"ywordSearch: 'carpenter tools',\n            language: 'en'\n        });\n        Kj.Listings.initSearchResults({\n            featu"
# b"reCounterUrl: '/j-feature-link-inc.json',\n            hasDealerRatings: false,\n            hasSponsors: true\n        });\n       "
# b' \n            Kj.Listings.ThirdParty.initListings({\n                counts: [\n                    \n                    {\n       '
# b'                 thirdPartyId : "cas",\n                        merchantName: undefined,\n                        numLoaded : 2\n  '
# b"                  }\n                ],\n                thirdPartiesSearched:[\n                    \n                        'cas'"
# b'\n                        \n                ]\n            });\n        \n\n        Kj.Listings.initEmbeddedTopAd();\n\n        Kj.Recen'
# b'tlyViewed.initRecentlyViewed("https://ca.classistatic.com/static/V/7738/img/placeholder.gif");\n\n        \n\n        Kj.Search.init'
# b'SearchNavigationFlag();\n        Kj.Search.initFakePageLinks();\n\n        Kj.Search.SearchNav.init();\n        Kj.Banners.Responsiv'
# b'e.init({\n            banners: window.gptBannerSizeMapping\n        });\n\n        \n    });\n</script>\n</body>\n</html>\n'

# %%
soup = bs(response.text. 'lxml')

# %%
results = soup.find_all('div', class_ = 'info-container')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4145d05fccf9> in <module>()
# ----> 1 results = soup.find_all('div', class_ = 'info-container')
#
# NameError: name 'soup' is not defined

# %%
html_string = ""

# %%
parsed = bs(html_string, 'html.parser')

# %%
for line in parsed:
    print(line)

# %%
print(parsed.prettify())

# %%
print(parsed.title)

# %%
print(parsed.head)

# %%
print(parsed.p)

# %%
print(parsed.p.text)

# %%
print(parsed.head.text)

# %%
print(parsed.head.text.strip())

# %%
print(parsed.body.find_all)('p')

# %%
print(parsed.body.find_all('p')[0])

# %%
# Scrape the NASA Mars News Site and collect the latest News Title and Paragraph Text. Assign the text to variables that you can reference later.

# %%
# Example:
#news_title = "NASA's Next Mars Mission to Investigate Interior of Red Planet"

#news_p = "Preparation of NASA's next spacecraft to Mars, InSight, has ramped up this summer, on course for launch next May from Vandenberg Air Force Base in central California -- the first interplanetary launch in history from America's West Coast."

# %%
#Visit the url for JPL Featured Space Image here.
#Use splinter to navigate the site and find the image url for the current Featured Mars Image and assign the url string to a variable called featured_image_url.
#Make sure to find the image url to the full size .jpg image.
#Make sure to save a complete url string for this image.

# %%
# Example:
#featured_image_url = 'https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA16225_hires.jpg'

# %%
#Visit the Mars Weather twitter account here and scrape the latest Mars weather tweet from the page. 
#Save the tweet text for the weather report as a variable called mars_weather.

# %%
# Example:
#mars_weather = 'Sol 1801 (Aug 30, 2017), Sunny, high -21C/-5F, low -80C/-112F, pressure at 8.82 hPa, daylight 06:09-17:55'

# %%
#Visit the Mars Facts webpage here and use Pandas to scrape the table containing facts about the planet including Diameter, Mass, etc.
#Use Pandas to convert the data to a HTML table string.

# %%
#Visit the USGS Astrogeology site here to obtain high resolution images for each of Mar's hemispheres.
#You will need to click each of the links to the hemispheres in order to find the image url to the full resolution image.
#Save both the image url string for the full resolution hemisphere image, and the Hemisphere title containing the hemisphere name. Use a Python dictionary to store the data using the keys img_url and title.
#Append the dictionary with the image url string and the hemisphere title to a list. This list will contain one dictionary for each hemisphere.

# %%
# Example:
#hemisphere_image_urls = [
#    {"title": "Valles Marineris Hemisphere", "img_url": "..."},
#    {"title": "Cerberus Hemisphere", "img_url": "..."},
#    {"title": "Schiaparelli Hemisphere", "img_url": "..."},
#    {"title": "Syrtis Major Hemisphere", "img_url": "..."},
#]

# %%
#Use MongoDB with Flask templating to create a new HTML page that displays all of the information that was scraped from the URLs above.


#Start by converting your Jupyter notebook into a Python script called scrape_mars.py with a function called scrape that will execute all of your scraping code from above and return one Python dictionary containing all of the scraped data.

#Next, create a route called /scrape that will import your scrape_mars.py script and call your scrape function.


#Store the return value in Mongo as a Python dictionary.


#Create a root route / that will query your Mongo database and pass the mars data into an HTML template to display the data.
#Create a template HTML file called index.html that will take the mars data dictionary and display all of the data in the appropriate HTML elements. Use the following as a guide for what the final product should look like, but feel free to create your own design.

# %%
#Use Splinter to navigate the sites when needed and BeautifulSoup to help find and parse out the necessary data.
#Use Pymongo for CRUD applications for your database. For this homework, you can simply overwrite the existing document each time the /scrape url is visited and new data is obtained.
#Use Bootstrap to structure your HTML template.
